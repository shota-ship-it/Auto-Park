# %%
# !pip install ultralytics -q
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 702.8/702.8 kB 4.0 MB/s eta 0:00:00

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8x.pt")
# Out:
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 244MB/s]

# %%
# !touch data.yaml

# %%
model.train(data = "/content/data.yaml", epochs = 5)
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
infer = YOLO("/content/runs/detect/train2/weights/best.pt")

# %%
infer.predict("/content/drive/MyDrive/Parking-Lot/PkLot-1/test/images", save = True)
# Out:
# image 1/113 /content/drive/MyDrive/Parking-Lot/PkLot-1/test/images/2012-09-11_15_53_00_jpg.rf.8d1b56dcd21d8440995498ef8807577f.jpg: 384x640 29 vacants, 72 occupieds, 99.9ms
# image 2/113 /content/drive/MyDrive/Parking-Lot/PkLot-1/test/images/2012-09-11_16_48_36_jpg.rf.a7fb6e8a98d96957a8730a06ee0ab4bb.jpg: 384x640 25 vacants, 76 occupieds, 62.0ms
# image 3/113 /content/drive/MyDrive/Parking-Lot/PkLot-1/test/images/2012-09-12_06_36_36_jpg.rf.9e84b05f037d28aae2e40621ec613002.jpg: 384x640 100 vacants, 61.9ms
# image 4/113 /content/drive/MyDrive/Parking-Lot/PkLot-1/test/images/2012-09-12_08_15_53_jpg.rf.99e02d9ed6b5c5d5923ff04866d185d1.jpg: 384x640 7 vacants, 93 occupieds, 61.9ms
# image 5/113 /content/drive/MyDrive/Parking-Lot/PkLot-1/test/images/2012-09-12_09_18_46_jpg.rf.5e281c81bd6e485c951a825033a9523c.jpg: 384x640 5 vacants, 96 occupieds, 61.9ms
# ...

# %%
import locale
locale.getpreferredencoding = lambda: "UTF-8"

# %%
# !yolo detect predict model="/content/runs/detect/train2/weights/best.pt" source="/content/drive/MyDrive/Parking-Lot/parking.mp4"
# Out:
# Ultralytics YOLOv8.1.5 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 268 layers, 68125494 parameters, 0 gradients, 257.4 GFLOPs
#
# video 1/1 (1/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 3 vacants, 179.9ms
# video 1/1 (2/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 3 vacants, 61.8ms
# video 1/1 (3/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 3 vacants, 61.8ms
# video 1/1 (4/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 4 vacants, 46.2ms
# video 1/1 (5/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 4 vacants, 46.3ms
# video 1/1 (6/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 2 vacants, 41.1ms
# video 1/1 (7/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 2 vacants, 40.8ms
# video 1/1 (8/4049) /content/drive/MyDrive/Parking-Lot/parking.mp4: 384x640 2 vacants, 38.8ms
# ...

# %%
# !ffmpeg -i {"/content/runs/detect/predict2/parking.avi"} -vcodec libx265 {"parking-detect.mp4"}
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
